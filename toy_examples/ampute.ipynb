# %%
"""
=========================================
A custom pipeline with more possibilities
=========================================
Earlier, we demonstrated how :class:`~pyampute.ampute.MultivariateAmputation` can be integrated in a scikit-learn pipeline (see `A quick example`_ and `Evaluating missing values with grid search and a pipeline`_).
It may be valuable to understand the impact of missing values in more detail. Therefore, we demonstrate how a ``CustomTransformer`` and ``CustomEstimator`` can be used to do a more thorough analysis. Not only will such analysis gain insights in the statistical problems of missing data (and some imputation methods), but it will also help you to create real-world and realistic missingness scenarios.
Another example, of a more systematic approach, can be found in `Schouten and Vink (2021)`_.
.. _`A quick example`: https://rianneschouten.github.io/pyampute/build/html/auto_examples/plot_easy_example.html
.. _`Evaluating missing values with grid search and a pipeline`: https://rianneschouten.github.io/pyampute/build/html/auto_examples/plot_simulation_pipeline.html
.. _`Schouten and Vink (2021)`: https://journals.sagepub.com/doi/full/10.1177/0049124118799376
"""

# Author: Rianne Schouten <https://rianneschouten.github.io/>

# %%
# Recap
#######
#
# Given is the following setting (from `Evaluating missing values with grid search and a pipeline`_):
#
# .. _`Evaluating missing values with grid search and a pipeline`: https://rianneschouten.github.io/pyampute/build/html/auto_examples/plot_simulation_pipeline.html

import numpy as np

m = 5
n = 10000

mean = np.repeat(5, m)
cor = 0.5
cov = np.identity(m)
cov[cov == 0] = cor
compl_dataset = np.random.multivariate_normal(mean, cov, n)

# %%
# As amputation parameter settings, we will vary the proportion, the mechanism and the ``score_to_probability_func``. Since in  the latter have to be specified within the same dictionary, we define the parameters for the grid search as follows.
#

import itertools as it

mechs = ["MCAR", "MAR", "MNAR"]
funcs = ["sigmoid-right", "sigmoid-mid"]

parameters = {
    "amputation__prop": [0.1, 0.5, 0.9],
    "amputation__patterns": [
        [{"incomplete_vars": [0,1], "mechanism": mechanism, "score_to_probability_func": func}]
        for mechanism, func in list(it.product(mechs, funcs))]
}

# %%
# A transformer that drops incomplete rows
##########################################
#
# Previously, we evaluated the ``SimpleImputer`` class from scikit-learn. Another good way to evaluate the effect of missing values, is by analyzing the incomplete dataset directly. Since most prediction and analysis models do not accept missing values, we apply the `dropna` or `listwise deletion` or `complete case analysis` method (all names refer to the same strategy). To allow for integration in a pipeline, we set up a custom ``TransformerMixin``.
#

from sklearn.base import TransformerMixin

class DropTransformer(TransformerMixin):

    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        self.X = X
        
        return self

    def transform(self, X, y=None):

        # drop incomplete rows
        Xp = pd.DataFrame(X)
        Xdrop = Xp.dropna().to_numpy()
		
        return Xdrop

# %%
# A custom estimator
####################
#
# Almost all, if not all, estimators and evaluation metrics in scikit-learn are aimed at prediction or classification. That is what most people want to do.
#
# However, for evaluating the effect of missing values on your model, it may be good to look further than just the prediction or classification accuracy. In this example, we will focus on the center of the distribution of one feature and evaluate the bias in that distribution.
#
# That could work as follows.
#

from sklearn.base import BaseEstimator 

class CustomEstimator(BaseEstimator):

    def __init__(self):
        super().__init__()

    def fit(self, X, y=None):
        self.X = X
        
        return self

    def predict(self, X):

        # return values of first feature
        values_used_for_score = X[:,0]
		
        return values_used_for_score

def my_evaluation_metric(y_true, y_pred):

    m1 = np.mean(y_true)
    m2 = np.mean(y_pred)

    bias = np.abs(m1 - m2)

    return bias

# %%
# An evaluation pipeline
########################
#
# As can be seen, the ``predict`` function returns the first feature of the transformed dataset. The evaluation metric then calculated the mean difference between that feature, and the truth.
#
# In our experiment, the complete dataset is the ground truth and we evaluate the impact of several missing data models (and imputation models) on that truth. 
#
# We then run the pipeline twice.
#

import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from pyampute.ampute import MultivariateAmputation
from sklearn.metrics import make_scorer

# %%
# Once with the DropTransformer

steps = [('amputation', MultivariateAmputation()), ('imputation', DropTransformer()), ('estimator', CustomEstimator())]
pipe = Pipeline(steps)
grid = GridSearchCV(
    estimator=pipe,
    param_grid=parameters,
    scoring=make_scorer(my_evaluation_metric),
)

grid.fit(compl_dataset, np.zeros(len(compl_dataset)))
grid.score(compl_dataset, compl_dataset[:,0])
results_drop = pd.DataFrame(grid.cv_results_)

# %%
# Once with the SimpleImputer

steps = [('amputation', MultivariateAmputation()), ('imputation', SimpleImputer()), ('estimator', CustomEstimator())]
pipe = Pipeline(steps)
grid = GridSearchCV(
    estimator=pipe,
    param_grid=parameters,
    scoring=make_scorer(my_evaluation_metric),
)

grid.fit(compl_dataset, np.zeros(len(compl_dataset)))
grid.score(compl_dataset, compl_dataset[:,0])
results_mean = pd.DataFrame(grid.cv_results_)

# %%
# Comparison
############
#

res_drop = results_drop[['param_amputation__patterns', 'param_amputation__prop', 'mean_test_score']]
res_mean = results_mean[['param_amputation__patterns', 'param_amputation__prop', 'mean_test_score']]

res_drop.columns = ['mechanism, func', 'prop', 'score']
res_mean.columns = ['mechanism, func', 'prop', 'score']

res_drop

# %%

res_mean

# %%
#
# What you find here, is that a MCAR mechanism will not affect the center of the distribution of the first feature much, independent of the proportion of incomplete rows. 
# 
# A MAR mechanism with a sigmoid-right probability function will, on average, remove the right-hand side of the distribution (also, because there is a positive correlation between the observed data and the first feature). Therefore, the larger the proportion, the more bias. However, with a sigmoid-mid probability function, values in the center of the distribution of the first feature are removed, and there is therefore not much effect on the bias. 
#
# The same logic applies to MNAR missingness, but since MNAR missingness does not depend on the size of the correlation between observed data and incomplete data, the bias will be stronger.
#
# `Schouten and Vink (2021)`_ further discuss this topic and the effect of multiple imputation (which can be performed using scikit-learn's IterativeImputer).
#
# SimpleImputer will use the mean of the observed data in the first feature. Therefore, in case there is any bias, that bias will remain. In case there is no bias, mean imputation will distort the correlation structure with other features. But that is another story...
#
# .. _`Schouten and Vink (2021)`: https://journals.sagepub.com/doi/full/10.1177/0049124118799376
# Out:
# 2022-04-18 12:06:38,171 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:38,372 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:38,500 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:38,612 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:38,714 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:38,878 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,021 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,141 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,296 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,418 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,560 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,722 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:39,967 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,058 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,144 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,231 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,313 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,404 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,491 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,568 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,642 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,715 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,801 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,883 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:40,966 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,047 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,129 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,208 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,285 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,432 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,731 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:41,897 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,003 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,102 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,200 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,289 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,392 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,515 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,599 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,674 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,751 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,836 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:42,918 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,008 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,103 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,187 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,266 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,352 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,454 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,576 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:43,968 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,067 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,158 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,251 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,335 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,459 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,543 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,635 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,716 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,797 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,877 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:44,956 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,037 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,121 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,204 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,276 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,345 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,422 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,497 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,575 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,653 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,731 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,813 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,893 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:45,980 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,050 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,117 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,185 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,255 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,328 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,398 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,468 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,533 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,601 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,670 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,736 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,811 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,882 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:46,950 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,019 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,086 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,211 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,279 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,350 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,429 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,503 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,592 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:47,715 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,062 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,207 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,320 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,418 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,493 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,548 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,598 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,653 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,710 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,764 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,813 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,862 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,931 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:48,983 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,036 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,086 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,142 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,194 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,246 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,317 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,369 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,431 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,501 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,563 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,625 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,680 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,746 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,805 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,862 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,924 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:49,985 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,047 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,104 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,169 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,238 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,327 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,399 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,475 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,540 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,616 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,673 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,745 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,831 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,904 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:50,965 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,031 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,088 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,143 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,197 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,250 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,313 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,368 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,430 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,486 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,547 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,617 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,675 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,737 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,792 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,848 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,904 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:51,957 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,009 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,072 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,132 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,193 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,258 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,341 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,424 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,589 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,674 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,750 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,830 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,905 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:52,975 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,043 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,121 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,202 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,298 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,379 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,452 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,544 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,659 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
# 2022-04-18 12:06:53,733 [WARNING] Failed to load lookup table for a prespecified score to probability function. It is possible /data//Users/vladislavbushmakin/Documents/GitHub/Mice/toy_examples/data/shift_lookup.csv.csv is missing, in the wrong location, or corrupted. Try rerunning /amputation/scripts.py to regenerate the lookup table.
#                                       mechanism, func prop     score
# 0   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.1  5.007574
# 1   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.5  5.016958
# 2   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.9  5.008997
# 3   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.1  5.008678
# 4   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.5  5.009967
# 5   [{'incomplete_vars': [0, 1], 'mechanism': 'MCA...  0.9  5.007400
# 6   [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.1  4.954188
# 7   [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.5  4.762607
# 8   [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.9  4.509388
# 9   [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.1  5.006261
# 10  [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.5  5.012700
# 11  [{'incomplete_vars': [0, 1], 'mechanism': 'MAR...  0.9  4.996110
# 12  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.1  4.923504
# 13  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.5  4.658196
# 14  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.9  4.276127
# 15  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.1  5.007051
# 16  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.5  5.013802
# 17  [{'incomplete_vars': [0, 1], 'mechanism': 'MNA...  0.9  4.997033
